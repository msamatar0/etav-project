# %%
import numpy as np, pandas as pd, matplotlib.pyplot as plt, seaborn as sns

# %%
sns.get_dataset_names()
# Out:
# ['anagrams',
#  'anscombe',
#  'attention',
#  'brain_networks',
#  'car_crashes',
#  'diamonds',
#  'dots',
#  'dowjones',
#  'exercise',
#  'flights',
#  'fmri',
#  'geyser',
#  'glue',
#  'healthexp',
#  'iris',
#  'mpg',
#  'penguins',
#  'planets',
#  'seaice',
#  'taxis',
#  'tips',
#  'titanic']

# %%
df = sns.load_dataset("planets")
x ="distance"
y = "mass"
title="Planet"

# %%
df
# Out:
#                method  number  orbital_period   mass  distance  year
# 0     Radial Velocity       1      269.300000   7.10     77.40  2006
# 1     Radial Velocity       1      874.774000   2.21     56.95  2008
# 2     Radial Velocity       1      763.000000   2.60     19.84  2011
# 3     Radial Velocity       1      326.030000  19.40    110.62  2007
# 4     Radial Velocity       1      516.220000  10.50    119.47  2009
# ...               ...     ...             ...    ...       ...   ...
# 1030          Transit       1        3.941507    NaN    172.00  2006
# 1031          Transit       1        2.615864    NaN    148.00  2007
# 1032          Transit       1        3.191524    NaN    174.00  2007
# 1033          Transit       1        4.125083    NaN    293.00  2008
# 1034          Transit       1        4.187757    NaN    260.00  2008
#
# [1035 rows x 6 columns]

# %%
df.drop_duplicates("mass")
# Out:
#               method  number  orbital_period    mass  distance  year
# 0    Radial Velocity       1        269.3000   7.100     77.40  2006
# 1    Radial Velocity       1        874.7740   2.210     56.95  2008
# 2    Radial Velocity       1        763.0000   2.600     19.84  2011
# 3    Radial Velocity       1        326.0300  19.400    110.62  2007
# 4    Radial Velocity       1        516.2200  10.500    119.47  2009
# ..               ...     ...             ...     ...       ...   ...
# 638  Radial Velocity       1        511.0980   8.820     31.33  2002
# 641  Radial Velocity       1          5.0505   1.068     44.46  2013
# 913  Radial Velocity       1        677.8000  19.800       NaN  2007
# 914  Radial Velocity       1          6.9580   0.340       NaN  2014
# 916  Radial Velocity       1        121.7100   1.540       NaN  2014
#
# [382 rows x 6 columns]

# %%
col = "distance"
max = df[col].max()
min = df[col].min()
avg = df[col].mean()
print(f"Max: {max}\nMin: {min}\nAverage: {avg}")
# Out:
# Max: 8500.0
# Min: 1.35
# Average: 264.06928217821786

# %%
plt.plot(df.index, df[y])
plt.grid()
plt.xlabel(x)
plt.ylabel(y)
plt.title(title)
plt.show()
